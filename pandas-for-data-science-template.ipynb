# %% [markdown]
# <a href="https://www.kaggle.com/code/pttljessy/pandas-for-data-science-template?scriptVersionId=148494064" target="_blank"><img align="left" alt="Kaggle" title="Open in Kaggle" src="https://kaggle.com/static/images/open-in-kaggle.svg"></a>

# %% [raw]
# Table of Contents
# Step 1: Importing necessary libraries and packages
#
# Step 2: Understanding data
#
# Step 3: Cleaning data (Check, visualise, and handle missing/null values)
#
# Step 4: Asking analytical questions and visualisations
#
# Step 5: Insights summary and conclusion

# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import matplotlib.pyplot as plt
# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

#Visualisation
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
import missingno as msno
# Out:
# /kaggle/input/tiktok-popular-songs-2022/TikTok_songs_2022.csv
# /kaggle/input/global-cost-of-living/cost-of-living_v2.csv
# /kaggle/input/global-cost-of-living/cost-of-living.csv
# /kaggle/input/tiktok-google-play-store-review/tiktok_google_play_reviews.csv
# /opt/conda/lib/python3.10/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.23.5
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"

# %% [markdown]
# # **1. Create**

# %% [markdown]
# 1.1 Create from a CSV

# %%
# Loading the .csv files using Pandas
df_global_col = pd.read_csv("/kaggle/input/global-cost-of-living/cost-of-living.csv")
df_global_col2 = pd.read_csv("/kaggle/input/global-cost-of-living/cost-of-living_v2.csv")
df_tiktok_reviews = pd.read_csv("/kaggle/input/tiktok-google-play-store-review/tiktok_google_play_reviews.csv")
df_tiktok_songs = pd.read_csv("/kaggle/input/tiktok-popular-songs-2022/TikTok_songs_2022.csv")
# Out:
# /tmp/ipykernel_20/2294819247.py:4: DtypeWarning: Columns (8,9) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_tiktok_reviews = pd.read_csv("/kaggle/input/tiktok-google-play-store-review/tiktok_google_play_reviews.csv")

# %% [markdown]
# # **2. Read**

# %% [markdown]
# 2.1 Show Top 5 and Bottom 5 Rows

# %%
df_tiktok_songs.head(5)
# Out:
#                                track_name    artist_name  artist_pop  \
# 0  Running Up That Hill (A Deal With God)      Kate Bush          81
# 1                               As It Was   Harry Styles          91
# 2                                 Sunroof    Nicky Youre          73
# 3                              Heat Waves  Glass Animals          80
# 4                         About Damn Time          Lizzo          81
#
#                         album  track_pop  danceability  energy  loudness  \
# 0              Hounds Of Love         95         0.629   0.547   -13.123
# 1                   As It Was         96         0.520   0.731    -5.338
# 2                     Sunroof         44         0.768   0.716    -5.110
# 3  Dreamland (+ Bonus Levels)         89         0.761   0.525    -6.900
# 4             About Damn Time         92         0.836   0.743    -6.305
#
#    mode  key  speechiness  acousticness  instrumentalness  liveness  valence  \
# ...

# %%
df_tiktok_songs.tail(5)
# Out:
#                         track_name      artist_name  artist_pop  \
# 258     The Less I Know The Better      Tame Impala          78
# 259                     Dandelions          Ruth B.          75
# 260  Jimmy Cooks (feat. 21 Savage)            Drake          95
# 261                   Good Looking  Suki Waterhouse          64
# 262                        INFERNO        Sub Urban          67
#
#                    album  track_pop  danceability  energy  loudness  mode  \
# 258             Currents         84         0.640   0.740    -4.083     1
# 259           Safe Haven         90         0.609   0.692    -2.958     1
# 260  Honestly, Nevermind         92         0.529   0.673    -4.711     1
# 261         Good Looking         80         0.377   0.558    -9.076     1
# 262              INFERNO         71         0.820   0.611    -5.020     0
#
#      key  speechiness  acousticness  instrumentalness  liveness  valence  \
# ...

# %% [markdown]
# 2.1 Show Colummns and Data Type

# %%
df_tiktok_songs.columns
# Out:
# Index(['track_name', 'artist_name', 'artist_pop', 'album', 'track_pop',
#        'danceability', 'energy', 'loudness', 'mode', 'key', 'speechiness',
#        'acousticness', 'instrumentalness', 'liveness', 'valence', 'tempo',
#        'time_signature', 'duration_ms'],
#       dtype='object')

# %% [markdown]
# 2.3 Summary Statistics

# %%
df_tiktok_songs.dtypes
# Out:
# track_name           object
# artist_name          object
# artist_pop            int64
# album                object
# track_pop             int64
# danceability        float64
# energy              float64
# loudness            float64
# mode                  int64
# key                   int64
# speechiness         float64
# acousticness        float64
# instrumentalness    float64
# liveness            float64
# valence             float64
# tempo               float64
# time_signature        int64
# duration_ms           int64
# dtype: object

# %%
df_tiktok_songs.describe()
# Out:
#        artist_pop   track_pop  danceability      energy    loudness  \
# count  263.000000  263.000000    263.000000  263.000000  263.000000
# mean    64.186312   59.844106      0.715338    0.682631   -6.300513
# std     18.146338   24.976524      0.117722    0.141756    1.905114
# min     18.000000    0.000000      0.308000    0.214000  -13.468000
# 25%     50.000000   47.000000      0.646000    0.593000   -7.423500
# 50%     64.000000   66.000000      0.726000    0.701000   -6.067000
# 75%     81.000000   79.500000      0.796500    0.790500   -4.887000
# max     95.000000   97.000000      0.961000    0.955000   -2.634000
#
#              mode         key  speechiness  acousticness  instrumentalness  \
# count  263.000000  263.000000   263.000000    263.000000        263.000000
# mean     0.536122    5.809886     0.117268      0.193188          0.020244
# std      0.499644    3.657312     0.101417      0.214588          0.109370
# ...

# %%
df_tiktok_songs.describe(include='object')
# Out:
#           track_name artist_name       album
# count            263         263         263
# unique           258         199         251
# top     Say It Right    Doja Cat  Planet Her
# freq               2           8           4

# %% [markdown]
# 2.4 Filtering Columns

# %%
df_tiktok_songs.loudness
# Out:
# 0     -13.123
# 1      -5.338
# 2      -5.110
# 3      -6.900
# 4      -6.305
#         ...
# 258    -4.083
# 259    -2.958
# 260    -4.711
# 261    -9.076
# 262    -5.020
# Name: loudness, Length: 263, dtype: float64

# %%
df_tiktok_songs[['loudness','artist_name']]
# Out:
#      loudness      artist_name
# 0     -13.123        Kate Bush
# 1      -5.338     Harry Styles
# 2      -5.110      Nicky Youre
# 3      -6.900    Glass Animals
# 4      -6.305            Lizzo
# ..        ...              ...
# 258    -4.083      Tame Impala
# 259    -2.958          Ruth B.
# 260    -4.711            Drake
# 261    -9.076  Suki Waterhouse
# 262    -5.020        Sub Urban
#
# [263 rows x 2 columns]

# %%
df_tiktok_songs.track_name.unique()
# Out:
# array(['Running Up That Hill (A Deal With God)', 'As It Was', 'Sunroof',
#        'Heat Waves', 'About Damn Time', 'Glimpse of Us', 'Bad Habit',
#        'STAY (with Justin Bieber)',
#        'Enemy (with JID) - from the series Arcane League of Legends',
#        'First Class', 'Afraid To Feel', 'Betty (Get Money)', 'abcdefu',
#        'Being Good Is Boring', 'MIDDLE OF THE NIGHT', 'Envolver', 'AMG',
#        'SNAP', 'Baby Girl', 'Flex On My Ex (with Bankrol Hayden)',
#        'House of Memories', 'The Plan', 'Thousand Miles',
#        'INDUSTRY BABY (feat. Jack Harlow)', 'Until I Found You', 'Oh No',
#        'Cooped Up (with Roddy Ricch)', 'TO THE MOON', 'Dreamer',
#        'Left and Right (Charlie Puth) [feat. Jung Kook of BTS] - Sped Up Version',
#        'Pepas', 'Bam Bam (feat. Ed Sheeran)', 'Fever - Remix',
#        'On My Way!', 'Another Love', 'Frozen', 'Riptide',
#        'Down Under (feat. Colin Hay)', 'Meet Me At Our Spot',
# ...

# %% [markdown]
# 2.5 Filtering on Rows

# %%
df_tiktok_songs[df_tiktok_songs['artist_name']=='Harry Styles']
# Out:
#             track_name   artist_name  artist_pop          album  track_pop  \
# 1            As It Was  Harry Styles          91      As It Was         96
# 52  Late Night Talking  Harry Styles          91  Harry's House         93
#
#     danceability  energy  loudness  mode  key  speechiness  acousticness  \
# 1          0.520   0.731    -5.338     0    6       0.0557         0.342
# 52         0.714   0.728    -4.595     1   10       0.0468         0.298
#
#     instrumentalness  liveness  valence    tempo  time_signature  duration_ms
# 1            0.00101     0.311    0.662  173.930               4       167303
# 52           0.00000     0.106    0.901  114.996               4       177955

# %%
df_tiktok_songs[df_tiktok_songs['duration_ms'] > 174656]
# Out:
#                                  track_name      artist_name  artist_pop  \
# 0    Running Up That Hill (A Deal With God)        Kate Bush          81
# 3                                Heat Waves    Glass Animals          80
# 4                           About Damn Time            Lizzo          81
# 5                             Glimpse of Us             Joji          85
# 6                                 Bad Habit       Steve Lacy          83
# ..                                      ...              ...         ...
# 255                                Rockstar     Ilkay Sencan          61
# 258              The Less I Know The Better      Tame Impala          78
# 259                              Dandelions          Ruth B.          75
# 260           Jimmy Cooks (feat. 21 Savage)            Drake          95
# 261                            Good Looking  Suki Waterhouse          64
#
#                           album  track_pop  danceability  energy  loudness  \
# ...

# %%
df_tiktok_songs[(df_tiktok_songs['artist_name']=='Harry Styles') & (df_tiktok_songs['duration_ms'] > 174656)]
# Out:
#             track_name   artist_name  artist_pop          album  track_pop  \
# 52  Late Night Talking  Harry Styles          91  Harry's House         93
#
#     danceability  energy  loudness  mode  key  speechiness  acousticness  \
# 52         0.714   0.728    -4.595     1   10       0.0468         0.298
#
#     instrumentalness  liveness  valence    tempo  time_signature  duration_ms
# 52               0.0     0.106    0.901  114.996               4       177955

# %% [markdown]
# 2.6 Indexing with iloc

# %%
df_tiktok_songs.iloc[4]
# Out:
# track_name          About Damn Time
# artist_name                   Lizzo
# artist_pop                       81
# album               About Damn Time
# track_pop                        92
# danceability                  0.836
# energy                        0.743
# loudness                     -6.305
# mode                              0
# key                              10
# speechiness                  0.0656
# acousticness                 0.0995
# instrumentalness                0.0
# liveness                      0.335
# valence                       0.722
# tempo                       108.966
# time_signature                    4
# duration_ms                  191822
# Name: 4, dtype: object

# %%
df_tiktok_songs.iloc[4,-1] #row 4, 1st column tu phai qua
# df_tiktok_songs.iloc[4,0] #row 4, 1st column tu trai qua
# df_tiktok_songs.iloc[4,1] #row 4, 2nd column tu trai qua
# Out:
# 191822

# %%
df_tiktok_songs.iloc[0:4] # 1st to 3rd row
df_tiktok_songs.iloc[-3:-1] # 2nd last to last row
# Out:
#                         track_name      artist_name  artist_pop  \
# 260  Jimmy Cooks (feat. 21 Savage)            Drake          95
# 261                   Good Looking  Suki Waterhouse          64
#
#                    album  track_pop  danceability  energy  loudness  mode  \
# 260  Honestly, Nevermind         92         0.529   0.673    -4.711     1
# 261         Good Looking         80         0.377   0.558    -9.076     1
#
#      key  speechiness  acousticness  instrumentalness  liveness  valence  \
# 260    0       0.1750      0.000307          0.000002     0.093    0.366
# 261    4       0.0299      0.078900          0.000342     0.125    0.267
#
#        tempo  time_signature  duration_ms
# 260  165.921               4       218365
# 261  149.971               3       214800

# %% [markdown]
# 2.7 Indexing with loc

# %%
#set index on artist_name
test = df_tiktok_songs.copy()
test.set_index('artist_name', inplace=True)
test.head()
# Out:
#                                            track_name  artist_pop  \
# artist_name
# Kate Bush      Running Up That Hill (A Deal With God)          81
# Harry Styles                                As It Was          91
# Nicky Youre                                   Sunroof          73
# Glass Animals                              Heat Waves          80
# Lizzo                                 About Damn Time          81
#
#                                     album  track_pop  danceability  energy  \
# artist_name
# Kate Bush                  Hounds Of Love         95         0.629   0.547
# Harry Styles                    As It Was         96         0.520   0.731
# Nicky Youre                       Sunroof         44         0.768   0.716
# Glass Animals  Dreamland (+ Bonus Levels)         89         0.761   0.525
# Lizzo                     About Damn Time         92         0.836   0.743
#
#                loudness  mode  key  speechiness  acousticness  \
# artist_name
# ...

# %%
# we only want harry styles songs
test.loc['Harry Styles']
# Out:
#                       track_name  artist_pop          album  track_pop  \
# artist_name
# Harry Styles           As It Was          91      As It Was         96
# Harry Styles  Late Night Talking          91  Harry's House         93
#
#               danceability  energy  loudness  mode  key  speechiness  \
# artist_name
# Harry Styles         0.520   0.731    -5.338     0    6       0.0557
# Harry Styles         0.714   0.728    -4.595     1   10       0.0468
#
#               acousticness  instrumentalness  liveness  valence    tempo  \
# artist_name
# Harry Styles         0.342           0.00101     0.311    0.662  173.930
# Harry Styles         0.298           0.00000     0.106    0.901  114.996
#
#               time_signature  duration_ms
# artist_name
# Harry Styles               4       167303
# Harry Styles               4       177955

# %% [markdown]
# # **3. Update**

# %% [markdown]
# 3.1 Dropping Rows

# %%
df_tiktok_songs.isnull().sum()
# Out:
# track_name          0
# artist_name         0
# artist_pop          0
# album               0
# track_pop           0
# danceability        0
# energy              0
# loudness            0
# mode                0
# key                 0
# speechiness         0
# acousticness        0
# instrumentalness    0
# liveness            0
# valence             0
# tempo               0
# time_signature      0
# duration_ms         0
# dtype: int64

# %%
df_tiktok_songs.dropna(inplace=True)

# %% [markdown]
# 3.2 Dropping Columns

# %%
df_tiktok_songs.drop('loudness',axis=1)
# Out:
#                                  track_name      artist_name  artist_pop  \
# 0    Running Up That Hill (A Deal With God)        Kate Bush          81
# 1                                 As It Was     Harry Styles          91
# 2                                   Sunroof      Nicky Youre          73
# 3                                Heat Waves    Glass Animals          80
# 4                           About Damn Time            Lizzo          81
# ..                                      ...              ...         ...
# 258              The Less I Know The Better      Tame Impala          78
# 259                              Dandelions          Ruth B.          75
# 260           Jimmy Cooks (feat. 21 Savage)            Drake          95
# 261                            Good Looking  Suki Waterhouse          64
# 262                                 INFERNO        Sub Urban          67
#
#                           album  track_pop  danceability  energy  mode  key  \
# ...

# %% [markdown]
# 3.3 Creating Calculated Columns

# %%
df_tiktok_songs['New Column duration_hrs'] = df_tiktok_songs['duration_ms']/3600

# %%
df_tiktok_songs.head()
# Out:
#                                track_name    artist_name  artist_pop  \
# 0  Running Up That Hill (A Deal With God)      Kate Bush          81
# 1                               As It Was   Harry Styles          91
# 2                                 Sunroof    Nicky Youre          73
# 3                              Heat Waves  Glass Animals          80
# 4                         About Damn Time          Lizzo          81
#
#                         album  track_pop  danceability  energy  loudness  \
# 0              Hounds Of Love         95         0.629   0.547   -13.123
# 1                   As It Was         96         0.520   0.731    -5.338
# 2                     Sunroof         44         0.768   0.716    -5.110
# 3  Dreamland (+ Bonus Levels)         89         0.761   0.525    -6.900
# 4             About Damn Time         92         0.836   0.743    -6.305
#
#    mode  key  speechiness  acousticness  instrumentalness  liveness  valence  \
# ...

# %% [markdown]
# 3.4 Updating an Entire Column

# %%
df_tiktok_songs['New Column duration_hrs'] =100

# %% [markdown]
# 3.5 Updating a Single Value

# %%
df_tiktok_songs.iloc[0,-1] = 10

# %%
df_tiktok_songs.head()
# Out:
#                                track_name    artist_name  artist_pop  \
# 0  Running Up That Hill (A Deal With God)      Kate Bush          81
# 1                               As It Was   Harry Styles          91
# 2                                 Sunroof    Nicky Youre          73
# 3                              Heat Waves  Glass Animals          80
# 4                         About Damn Time          Lizzo          81
#
#                         album  track_pop  danceability  energy  loudness  \
# 0              Hounds Of Love         95         0.629   0.547   -13.123
# 1                   As It Was         96         0.520   0.731    -5.338
# 2                     Sunroof         44         0.768   0.716    -5.110
# 3  Dreamland (+ Bonus Levels)         89         0.761   0.525    -6.900
# 4             About Damn Time         92         0.836   0.743    -6.305
#
#    mode  key  speechiness  acousticness  instrumentalness  liveness  valence  \
# ...

# %% [markdown]
# 3.6 Condition based Updating using Apply

# %%
df_tiktok_songs['Track Duration'] = df_tiktok_songs['New Column duration_hrs'].apply(lambda x: 'long' if x > 10 else 'short')

# %%
df_tiktok_songs.head(5)
# Out:
#                                track_name    artist_name  artist_pop  \
# 0  Running Up That Hill (A Deal With God)      Kate Bush          81
# 1                               As It Was   Harry Styles          91
# 2                                 Sunroof    Nicky Youre          73
# 3                              Heat Waves  Glass Animals          80
# 4                         About Damn Time          Lizzo          81
#
#                         album  track_pop  danceability  energy  loudness  \
# 0              Hounds Of Love         95         0.629   0.547   -13.123
# 1                   As It Was         96         0.520   0.731    -5.338
# 2                     Sunroof         44         0.768   0.716    -5.110
# 3  Dreamland (+ Bonus Levels)         89         0.761   0.525    -6.900
# 4             About Damn Time         92         0.836   0.743    -6.305
#
#    mode  key  speechiness  acousticness  instrumentalness  liveness  valence  \
# ...

# %% [markdown]
# # **4. Delete/Output**

# %% [markdown]
# 4.1 Output to CSV

# %%
df_tiktok_songs.to_csv('output.csv')

# %% [markdown]
# 4.2 Output to JSON

# %%
df_tiktok_songs.to_json()
# Out:
# '{"track_name":{"0":"Running Up That Hill (A Deal With God)","1":"As It Was","2":"Sunroof","3":"Heat Waves","4":"About Damn Time","5":"Glimpse of Us","6":"Bad Habit","7":"STAY (with Justin Bieber)","8":"Enemy (with JID) - from the series Arcane League of Legends","9":"First Class","10":"Afraid To Feel","11":"Betty (Get Money)","12":"abcdefu","13":"Being Good Is Boring","14":"MIDDLE OF THE NIGHT","15":"Envolver","16":"AMG","17":"SNAP","18":"Baby Girl","19":"Flex On My Ex (with Bankrol Hayden)","20":"House of Memories","21":"The Plan","22":"Thousand Miles","23":"INDUSTRY BABY (feat. Jack Harlow)","24":"Until I Found You","25":"Oh No","26":"Cooped Up (with Roddy Ricch)","27":"TO THE MOON","28":"Dreamer","29":"Left and Right (Charlie Puth) [feat. Jung Kook of BTS] - Sped Up Version","30":"Pepas","31":"Bam Bam (feat. Ed Sheeran)","32":"Fever - Remix","33":"On My Way!","34":"Another Love","35":"Frozen","36":"Riptide","37":"Down Under (feat. Colin Hay)","38":"Meet Me At Our Spot","39":"When
# ...

# %% [markdown]
# 4.3 Output to HTML

# %%
df_tiktok_songs.to_html()
# Out:
# '<table border="1" class="dataframe">\n  <thead>\n    <tr style="text-align: right;">\n      <th></th>\n      <th>track_name</th>\n      <th>artist_name</th>\n      <th>artist_pop</th>\n      <th>album</th>\n      <th>track_pop</th>\n      <th>danceability</th>\n      <th>energy</th>\n      <th>loudness</th>\n      <th>mode</th>\n      <th>key</th>\n      <th>speechiness</th>\n      <th>acousticness</th>\n      <th>instrumentalness</th>\n      <th>liveness</th>\n      <th>valence</th>\n      <th>tempo</th>\n      <th>time_signature</th>\n      <th>duration_ms</th>\n      <th>New Column duration_hrs</th>\n      <th>Track Duration</th>\n    </tr>\n  </thead>\n  <tbody>\n    <tr>\n      <th>0</th>\n      <td>Running Up That Hill (A Deal With God)</td>\n      <td>Kate Bush</td>\n      <td>81</td>\n      <td>Hounds Of Love</td>\n      <td>95</td>\n      <td>0.629</td>\n      <td>0.547</td>\n      <td>-13.123</td>\n      <td>0</td>\n      <td>10</td>\n      <td>0.0550</td>\n      <td>0.720
# ...

# %% [markdown]
# 4.4 Delete a DataFrame

# %%
del test

# %% [markdown]
# # **Numpy Crash Course**

# %% [markdown]
# * NumPy (Numerical Python) is an open source Python library. It’s the universal standard for working with numerical data in Python, and it’s at the core of the scientific Python and PyData ecosystems.  The NumPy API is used extensively in Pandas, SciPy, Matplotlib, scikit-learn, scikit-image and most other data science and scientific Python packages.
#
# * Pandas Vs NumPy:
# Pandas is mostly used for data analysis tasks in Python. NumPy is mostly used for working with Numerical values as it makes it easy to apply mathematical functions. Pandas library works well for numeric, alphabets, and heterogeneous types of data simultaneously. Numpy library works better with only numerical data, has efficient storage, and fastly performs mathematical operations on array-based and array-based matrix-based numeric values.

# %%
import numpy as np

# %% [markdown]
# 1. Create

# %%
data = np.random.rand(2,3,4)
zeroes = np.zeros((2,2,2))
full = np.full((2,2,2), 7)
ones = np.ones((2,2,2))

# %%
data
# Out:
# array([[[0.27380694, 0.2294186 , 0.67332475, 0.7734928 ],
#         [0.85551062, 0.32609898, 0.10426624, 0.20195476],
#         [0.96369815, 0.42337028, 0.20123345, 0.57527194]],
#
#        [[0.03148987, 0.70592249, 0.15430993, 0.40679773],
#         [0.08298744, 0.65949516, 0.19684953, 0.97660561],
#         [0.56364882, 0.93412106, 0.21854819, 0.55037973]]])

# %%
zeroes
# Out:
# array([[[0., 0.],
#         [0., 0.]],
#
#        [[0., 0.],
#         [0., 0.]]])
